# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
headers={
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36',
    'Accept-Language' : 'en-US'
}

# %%
def pages_():
    url=input("Enter the Url here :  ") 
    response=requests.get(url,headers=headers)
    soup=BeautifulSoup(response.text,'html.parser')
    
    global hotels_data
    hotels=soup.findAll('div',{'data-testid':"property-card"})
    for hotel in hotels:
        #Extract hotel name
        name_element=hotel.find('div',{'data-testid':"title"})
        name=name_element.text.strip()
        #Price
        price_element=hotel.find('span',{'data-testid':"price-and-discounted-price"})
        price=price_element.text.strip()
        rating_element=hotel.find('div',{'class': 'a3b8729ab1 d86cee9b25'})
        rating=rating_element['aria-label'] if rating_element else 'NA'
        
        loc_element=hotel.find('span',{'data-testid': "address" })
        location=loc_element.text.strip()
        
        bdtype_element=hotel.find('span',{'class': 'df597226dd'})
        bed_type=bdtype_element.text.strip()
        noreview_element=hotel.find('div',{'class':'a3b8729ab1 e6208ee469 cb2cbb3ccb'})
        no_review=noreview_element['aria-label'] if rating_element else 'NA'
        #locUrl = hotel.find('span', {'class':'f4bd0794db b4273d69aa' })['href']

        hotels_data.append({
            'Name':name,
            'Price':price,
            'Ratings':rating,
            'Location':location,
            'Bedroom Type':bed_type,
            'No of Reviews':no_review,
            #'Map Location':locUrl


        })

# %%
def page_1():
    global hotels_data
    hotels_data = []
    pages_()

# %%
page_1()
# Out:
# Enter the Url here :   https://www.booking.com/searchresults.en-gb.html?ss=kerala&ssne=Nagaland&ssne_untouched=Nagaland&label=in-HvtKIh8HYqxrATaP24vtSgS379630681324%3Apl%3Ata%3Ap1%3Ap2%3Aac%3Aap%3Aneg%3Afi%3Atiaud-146342137510%3Akwd-303403359744%3Alp9152607%3Ali%3Adec%3Adm%3Appccp%3DUmFuZG9tSVYkc2RlIyh9YfpWGnRw6lOGgfEoJVv7zYo&sid=b934fe2fff7ea3c2aa0fad7f464a838b&aid=1610687&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=3476&dest_type=region&ac_position=0&ac_click_type=b&ac_langcode=en&ac_suggestion_list_length=5&search_selected=true&search_pageview_id=acea3661e27c00ba&ac_meta=GhBhY2VhMzY2MWUyN2MwMGJhIAAoATICZW46BmtlcmFsYUAASgBQAA%3D%3D&checkin=2023-08-23&checkout=2023-08-24&group_adults=2&no_rooms=1&group_children=0

# %%
pages_()
# Out:
# Enter the Url here :   https://www.booking.com/searchresults.en-gb.html?ss=kerala&ssne=Nagaland&ssne_untouched=Nagaland&label=in-HvtKIh8HYqxrATaP24vtSgS379630681324%3Apl%3Ata%3Ap1%3Ap2%3Aac%3Aap%3Aneg%3Afi%3Atiaud-146342137510%3Akwd-303403359744%3Alp9152607%3Ali%3Adec%3Adm%3Appccp%3DUmFuZG9tSVYkc2RlIyh9YfpWGnRw6lOGgfEoJVv7zYo&sid=b934fe2fff7ea3c2aa0fad7f464a838b&aid=1610687&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=3476&dest_type=region&ac_position=0&ac_click_type=b&ac_langcode=en&ac_suggestion_list_length=5&search_selected=true&search_pageview_id=acea3661e27c00ba&ac_meta=GhBhY2VhMzY2MWUyN2MwMGJhIAAoATICZW46BmtlcmFsYUAASgBQAA%3D%3D&checkin=2023-08-23&checkout=2023-08-24&group_adults=2&no_rooms=1&group_children=0

# %%
hotels_data
# Out:
# [{'Name': 'Oryx Homes',
#   'Price': '₹\xa01,568',
#   'Ratings': 'Scored 7.2 ',
#   'Location': 'Kakkanad',
#   'Bedroom Type': 'Standard Double Room',
#   'No of Reviews': 'Good'},
#  {'Name': 'Serene Crest Resort',
#   'Price': '₹\xa05,300',
#   'Ratings': 'Scored 9.1 ',
#   'Location': 'Mananthavady',
#   'Bedroom Type': 'Double Room with Pool View',
#   'No of Reviews': 'Superb'},
#  {'Name': 'Winter Vale Green Stay Resorts',
#   'Price': '₹\xa03,750',
#   'Ratings': 'Scored 8.5 ',
#   'Location': 'Vagamon',
#   'Bedroom Type': 'Deluxe Double Room with Balcony',
#   'No of Reviews': 'Very good'},
#  {'Name': 'Orchid Trails Resort',
#   'Price': '₹\xa02,950',
#   'Ratings': 'Scored 7.9 ',
#   'Location': 'Sultan Bathery',
#   'Bedroom Type': 'Deluxe Double Room',
#   'No of Reviews': 'Good'},
#  {'Name': 'Misty Gate',
#   'Price': '₹\xa02,850',
#   'Ratings': 'Scored 7.4 ',
#   'Location': 'Vythiri',
#   'Bedroom Type': 'Deluxe Double Room',
#   'No of Reviews': 'Good'},
#  {'Name': 'Thekkady Gavi Suites',
#   'Price': '₹\xa02,023',
#   'Ratings': 'Scored 8.3 ',
#   'Location': 'Vandiperiyār',
#   'Bedroom Type': 'Deluxe Double Studio',
#   'No of Reviews': 'Very good'},
#  {'Name': 'Dreamotel Luxury Suites and Rooms',
#   'Price': '₹\xa02,800',
#   'Ratings': 'Scored 8.6 ',
#   'Location': 'Kanjikode',
#   'Bedroom Type': 'Superior Double Room',
#   'No of Reviews': 'Fabulous'},
#  {'Name': 'Ela Seasons',
#   'Price': '₹\xa02,300',
#   'Ratings': 'Scored 9.5 ',
#   'Location': 'Ūdumbanshola',
#   'Bedroom Type': 'Deluxe Room',
#   'No of Reviews': 'Exceptional'},
#  {'Name': 'CONTOUR ISLAND RESORT & SPA by CITRINE',
#   'Price': '₹\xa015,300',
#   'Ratings': 'Scored 7.9 ',
#   'Location': 'Tariyod',
#   'Bedroom Type': 'Superior Room',
#   'No of Reviews': 'Good'},
#  {'Name': 'Wave Lakeview Resort & Spa by CITRINE',
#   'Price': '₹\xa05,500',
#   'Ratings': 'Scored 7.8 ',
#   'Location': 'Wayanad',
#   'Bedroom Type': 'Deluxe Double Room with Balcony',
#   'No of Reviews': 'Good'},
#  {'Name': 'Cranganor History Café & Riverside Château',
#   'Price': '₹\xa09,000',
#   'Ratings': 'Scored 9.4 ',
#   'Location': 'Parūr',
#   'Bedroom Type': 'Deluxe Double or Twin Room with Pool Access',
#   'No of Reviews': 'Superb'},
#  {'Name': 'Estuary Sarovar Portico',
#   'Price': '₹\xa07,200',
#   'Ratings': 'Scored 7.8 ',
#   'Location': 'Pūvār',
#   'Bedroom Type': 'Garden View Room',
#   'No of Reviews': 'Good'},
#  {'Name': 'French Avenue',
#   'Price': '₹\xa02,200',
#   'Ratings': 'NA',
#   'Location': 'Kallāyi',
#   'Bedroom Type': 'Standard Double Room',
#   'No of Reviews': 'NA'},
#  {'Name': 'Ananterra Resort Wayanad',
#   'Price': '₹\xa05,399',
#   'Ratings': 'Scored 8.7 ',
#   'Location': 'Wayanad',
#   'Bedroom Type': 'Premium Villas',
#   'No of Reviews': 'Fabulous'},
#  {'Name': 'Hasco Tower',
#   'Price': '₹\xa02,000',
#   'Ratings': 'Scored 8.3 ',
#   'Location': 'Palakkad',
#   'Bedroom Type': 'Deluxe Room',
#   'No of Reviews': 'Very good'},
#  {'Name': 'Abad Whispering Palms',
#   'Price': '₹\xa06,250',
#   'Ratings': 'Scored 8.0 ',
#   'Location': 'Kumarakom',
#   'Bedroom Type': 'Cottage with Garden View',
#   'No of Reviews': 'Very good'},
#  {'Name': 'CORALHEIGHTS AMBALAPPUZHA',
#   'Price': '₹\xa02,500',
#   'Ratings': 'Scored 7.7 ',
#   'Location': 'Ambalapulai',
#   'Bedroom Type': 'Standard Double or Twin Room',
#   'No of Reviews': 'Good'},
#  {'Name': 'Athirappilly Rainland Resort',
#   'Price': '₹\xa04,249',
#   'Ratings': 'Scored 8.6 ',
#   'Location': 'Athirappilly',
#   'Bedroom Type': 'Deluxe Double Room',
#   'No of Reviews': 'Fabulous'},
#  {'Name': 'Elephant Passage',
#   'Price': '₹\xa07,699',
#   'Ratings': 'Scored 8.6 ',
#   'Location': 'Munnar',
#   'Bedroom Type': 'Cottage Room',
#   'No of Reviews': 'Fabulous'},
#  {'Name': 'Itsy By Treebo - City Maskan',
#   'Price': '₹\xa02,092',
#   'Ratings': 'Scored 7.1 ',
#   'Location': 'Kazhakuttam',
#   'Bedroom Type': 'Deluxe Double Room',
#   'No of Reviews': 'Good'},
#  {'Name': 'Treebo Trend Nirupama Apartment',
#   'Price': '₹\xa01,867',
#   'Ratings': 'Scored 7.9 ',
#   'Location': 'Alwaye',
#   'Bedroom Type': 'Standard Double Room',
#   'No of Reviews': 'Good'},
#  {'Name': 'THEKKUMPURAM RESIDENCY',
#   'Price': '₹\xa0750',
#   'Ratings': 'Scored 8.0 ',
#   'Location': 'Kondotti',
#   'Bedroom Type': 'Budget Double Room',
#   'No of Reviews': 'Very good'},
#  {'Name': 'Itsy By Treebo - Sparrows Suite & Resorts With Mountain View',
#   'Price': '₹\xa01,686',
#   'Ratings': 'Scored 6.8 ',
#   'Location': 'Kattappana',
#   'Bedroom Type': 'Standard Double Room',
#   'No of Reviews': 'Review score'},
#  {'Name': 'Klov Resort & Spa',
#   'Price': '₹\xa013,500',
#   'Ratings': 'Scored 8.6 ',
#   'Location': 'Wayanad',
#   'Bedroom Type': 'Deluxe Room',
#   'No of Reviews': 'Fabulous'},
#  {'Name': 'Nexstay River Mouth International',
#   'Price': '₹\xa02,599',
#   'Ratings': 'Scored 8.3 ',
#   'Location': 'Ferokh',
#   'Bedroom Type': 'Superior Double Room',
#   'No of Reviews': 'Very good'},
#  {'Name': 'Oryx Homes',
#   'Price': '₹\xa01,568',
#   'Ratings': 'Scored 7.2 ',
#   'Location': 'Kakkanad',
#   'Bedroom Type': 'Standard Double Room',
#   'No of Reviews': 'Good'},
#  {'Name': 'CJ GRANDE BUSINESS HOTEL',
#   'Price': '₹\xa02,200',
#   'Ratings': 'Scored 7.8 ',
#   'Location': 'Ernakulam',
#   'Bedroom Type': 'Suite',
#   'No of Reviews': 'Good'},
#  {'Name': 'Serene Crest Resort',
#   'Price': '₹\xa05,300',
#   'Ratings': 'Scored 9.1 ',
#   'Location': 'Mananthavady',
#   'Bedroom Type': 'Double Room with Pool View',
#   'No of Reviews': 'Superb'},
#  {'Name': 'Winter Vale Green Stay Resorts',
#   'Price': '₹\xa03,750',
#   'Ratings': 'Scored 8.5 ',
#   'Location': 'Vagamon',
#   'Bedroom Type': 'Deluxe Double Room with Balcony',
#   'No of Reviews': 'Very good'},
#  {'Name': 'Orchid Trails Resort',
#   'Price': '₹\xa02,950',
#   'Ratings': 'Scored 7.9 ',
#   'Location': 'Sultan Bathery',
#   'Bedroom Type': 'Deluxe Double Room',
#   'No of Reviews': 'Good'},
#  {'Name': 'Misty Gate',
#   'Price': '₹\xa02,850',
#   'Ratings': 'Scored 7.4 ',
#   'Location': 'Vythiri',
#   'Bedroom Type': 'Deluxe Double Room',
#   'No of Reviews': 'Good'},
#  {'Name': 'Thekkady Gavi Suites',
#   'Price': '₹\xa02,023',
#   'Ratings': 'Scored 8.3 ',
#   'Location': 'Vandiperiyār',
#   'Bedroom Type': 'Deluxe Double Studio',
#   'No of Reviews': 'Very good'},
#  {'Name': 'Dreamotel Luxury Suites and Rooms',
#   'Price': '₹\xa02,800',
#   'Ratings': 'Scored 8.6 ',
#   'Location': 'Kanjikode',
#   'Bedroom Type': 'Superior Double Room',
#   'No of Reviews': 'Fabulous'},
#  {'Name': 'Ela Seasons',
#   'Price': '₹\xa02,300',
#   'Ratings': 'Scored 9.5 ',
#   'Location': 'Ūdumbanshola',
#   'Bedroom Type': 'Deluxe Room',
#   'No of Reviews': 'Exceptional'},
#  {'Name': 'CONTOUR ISLAND RESORT & SPA by CITRINE',
#   'Price': '₹\xa015,300',
#   'Ratings': 'Scored 7.9 ',
#   'Location': 'Tariyod',
#   'Bedroom Type': 'Superior Room',
#   'No of Reviews': 'Good'},
#  {'Name': 'Wave Lakeview Resort & Spa by CITRINE',
#   'Price': '₹\xa05,500',
#   'Ratings': 'Scored 7.8 ',
#   'Location': 'Wayanad',
#   'Bedroom Type': 'Deluxe Double Room with Balcony',
#   'No of Reviews': 'Good'},
#  {'Name': 'Cranganor History Café & Riverside Château',
#   'Price': '₹\xa09,000',
#   'Ratings': 'Scored 9.4 ',
#   'Location': 'Parūr',
#   'Bedroom Type': 'Deluxe Double or Twin Room with Pool Access',
#   'No of Reviews': 'Superb'},
#  {'Name': 'Estuary Sarovar Portico',
#   'Price': '₹\xa07,200',
#   'Ratings': 'Scored 7.8 ',
#   'Location': 'Pūvār',
#   'Bedroom Type': 'Garden View Room',
#   'No of Reviews': 'Good'},
#  {'Name': 'French Avenue',
#   'Price': '₹\xa02,200',
#   'Ratings': 'NA',
#   'Location': 'Kallāyi',
#   'Bedroom Type': 'Standard Double Room',
#   'No of Reviews': 'NA'},
#  {'Name': 'Ananterra Resort Wayanad',
#   'Price': '₹\xa05,399',
#   'Ratings': 'Scored 8.7 ',
#   'Location': 'Wayanad',
#   'Bedroom Type': 'Premium Villas',
#   'No of Reviews': 'Fabulous'},
#  {'Name': 'KGA Elite Continental Hotel',
#   'Price': '₹\xa02,890',
#   'Ratings': 'Scored 7.7 ',
#   'Location': 'Thiruvalla',
#   'Bedroom Type': 'Standard Room',
#   'No of Reviews': 'Good'},
#  {'Name': 'Hasco Tower',
#   'Price': '₹\xa02,000',
#   'Ratings': 'Scored 8.3 ',
#   'Location': 'Palakkad',
#   'Bedroom Type': 'Deluxe Room',
#   'No of Reviews': 'Very good'},
#  {'Name': 'Abad Whispering Palms',
#   'Price': '₹\xa06,250',
#   'Ratings': 'Scored 8.0 ',
#   'Location': 'Kumarakom',
#   'Bedroom Type': 'Cottage with Garden View',
#   'No of Reviews': 'Very good'},
#  {'Name': 'CORALHEIGHTS AMBALAPPUZHA',
#   'Price': '₹\xa02,500',
#   'Ratings': 'Scored 7.7 ',
#   'Location': 'Ambalapulai',
#   'Bedroom Type': 'Standard Double or Twin Room',
#   'No of Reviews': 'Good'},
#  {'Name': 'Athirappilly Rainland Resort',
#   'Price': '₹\xa04,249',
#   'Ratings': 'Scored 8.6 ',
#   'Location': 'Athirappilly',
#   'Bedroom Type': 'Deluxe Double Room',
#   'No of Reviews': 'Fabulous'},
#  {'Name': 'Elephant Passage',
#   'Price': '₹\xa07,699',
#   'Ratings': 'Scored 8.6 ',
#   'Location': 'Munnar',
#   'Bedroom Type': 'Cottage Room',
#   'No of Reviews': 'Fabulous'},
#  {'Name': 'Itsy By Treebo - City Maskan',
#   'Price': '₹\xa02,092',
#   'Ratings': 'Scored 7.1 ',
#   'Location': 'Kazhakuttam',
#   'Bedroom Type': 'Deluxe Double Room',
#   'No of Reviews': 'Good'},
#  {'Name': 'Treebo Trend Nirupama Apartment',
#   'Price': '₹\xa01,867',
#   'Ratings': 'Scored 7.9 ',
#   'Location': 'Alwaye',
#   'Bedroom Type': 'Standard Double Room',
#   'No of Reviews': 'Good'},
#  {'Name': 'THEKKUMPURAM RESIDENCY',
#   'Price': '₹\xa0750',
#   'Ratings': 'Scored 8.0 ',
#   'Location': 'Kondotti',
#   'Bedroom Type': 'Budget Double Room',
#   'No of Reviews': 'Very good'},
#  {'Name': 'Itsy By Treebo - Sparrows Suite & Resorts With Mountain View',
#   'Price': '₹\xa01,686',
#   'Ratings': 'Scored 6.8 ',
#   'Location': 'Kattappana',
#   'Bedroom Type': 'Standard Double Room',
#   'No of Reviews': 'Review score'}]

# %%
df  = pd.DataFrame(hotels_data)

# %%
df
# Out:
#                                                  Name     Price      Ratings  \
# 0                                          Oryx Homes   ₹ 1,568  Scored 7.2
# 1                                 Serene Crest Resort   ₹ 5,300  Scored 9.1
# 2                      Winter Vale Green Stay Resorts   ₹ 3,750  Scored 8.5
# 3                                Orchid Trails Resort   ₹ 2,950  Scored 7.9
# 4                                          Misty Gate   ₹ 2,850  Scored 7.4
# 5                                Thekkady Gavi Suites   ₹ 2,023  Scored 8.3
# 6                   Dreamotel Luxury Suites and Rooms   ₹ 2,800  Scored 8.6
# 7                                         Ela Seasons   ₹ 2,300  Scored 9.5
# 8              CONTOUR ISLAND RESORT & SPA by CITRINE  ₹ 15,300  Scored 7.9
# 9               Wave Lakeview Resort & Spa by CITRINE   ₹ 5,500  Scored 7.8
# 10         Cranganor History Café & Riverside Château   ₹ 9,000  Scored 9.4
# 11                            Estuary Sarovar Portico   ₹ 7,200  Scored 7.8
# 12                                      French Avenue   ₹ 2,200           NA
# 13                           Ananterra Resort Wayanad   ₹ 5,399  Scored 8.7
# 14                                        Hasco Tower   ₹ 2,000  Scored 8.3
# 15                              Abad Whispering Palms   ₹ 6,250  Scored 8.0
# 16                          CORALHEIGHTS AMBALAPPUZHA   ₹ 2,500  Scored 7.7
# 17                       Athirappilly Rainland Resort   ₹ 4,249  Scored 8.6
# 18                                   Elephant Passage   ₹ 7,699  Scored 8.6
# 19                       Itsy By Treebo - City Maskan   ₹ 2,092  Scored 7.1
# 20                    Treebo Trend Nirupama Apartment   ₹ 1,867  Scored 7.9
# 21                             THEKKUMPURAM RESIDENCY     ₹ 750  Scored 8.0
# 22  Itsy By Treebo - Sparrows Suite & Resorts With...   ₹ 1,686  Scored 6.8
# 23                                  Klov Resort & Spa  ₹ 13,500  Scored 8.6
# 24                  Nexstay River Mouth International   ₹ 2,599  Scored 8.3
# 25                                         Oryx Homes   ₹ 1,568  Scored 7.2
# 26                           CJ GRANDE BUSINESS HOTEL   ₹ 2,200  Scored 7.8
# 27                                Serene Crest Resort   ₹ 5,300  Scored 9.1
# 28                     Winter Vale Green Stay Resorts   ₹ 3,750  Scored 8.5
# 29                               Orchid Trails Resort   ₹ 2,950  Scored 7.9
# 30                                         Misty Gate   ₹ 2,850  Scored 7.4
# 31                               Thekkady Gavi Suites   ₹ 2,023  Scored 8.3
# 32                  Dreamotel Luxury Suites and Rooms   ₹ 2,800  Scored 8.6
# 33                                        Ela Seasons   ₹ 2,300  Scored 9.5
# 34             CONTOUR ISLAND RESORT & SPA by CITRINE  ₹ 15,300  Scored 7.9
# 35              Wave Lakeview Resort & Spa by CITRINE   ₹ 5,500  Scored 7.8
# 36         Cranganor History Café & Riverside Château   ₹ 9,000  Scored 9.4
# 37                            Estuary Sarovar Portico   ₹ 7,200  Scored 7.8
# 38                                      French Avenue   ₹ 2,200           NA
# 39                           Ananterra Resort Wayanad   ₹ 5,399  Scored 8.7
# 40                        KGA Elite Continental Hotel   ₹ 2,890  Scored 7.7
# 41                                        Hasco Tower   ₹ 2,000  Scored 8.3
# 42                              Abad Whispering Palms   ₹ 6,250  Scored 8.0
# 43                          CORALHEIGHTS AMBALAPPUZHA   ₹ 2,500  Scored 7.7
# 44                       Athirappilly Rainland Resort   ₹ 4,249  Scored 8.6
# 45                                   Elephant Passage   ₹ 7,699  Scored 8.6
# 46                       Itsy By Treebo - City Maskan   ₹ 2,092  Scored 7.1
# 47                    Treebo Trend Nirupama Apartment   ₹ 1,867  Scored 7.9
# 48                             THEKKUMPURAM RESIDENCY     ₹ 750  Scored 8.0
# 49  Itsy By Treebo - Sparrows Suite & Resorts With...   ₹ 1,686  Scored 6.8
#
#           Location                                 Bedroom Type No of Reviews
# 0         Kakkanad                         Standard Double Room          Good
# 1     Mananthavady                   Double Room with Pool View        Superb
# 2          Vagamon              Deluxe Double Room with Balcony     Very good
# 3   Sultan Bathery                           Deluxe Double Room          Good
# 4          Vythiri                           Deluxe Double Room          Good
# 5     Vandiperiyār                         Deluxe Double Studio     Very good
# 6        Kanjikode                         Superior Double Room      Fabulous
# 7     Ūdumbanshola                                  Deluxe Room   Exceptional
# 8          Tariyod                                Superior Room          Good
# 9          Wayanad              Deluxe Double Room with Balcony          Good
# 10           Parūr  Deluxe Double or Twin Room with Pool Access        Superb
# 11           Pūvār                             Garden View Room          Good
# 12         Kallāyi                         Standard Double Room            NA
# 13         Wayanad                               Premium Villas      Fabulous
# 14        Palakkad                                  Deluxe Room     Very good
# 15       Kumarakom                     Cottage with Garden View     Very good
# 16     Ambalapulai                 Standard Double or Twin Room          Good
# 17    Athirappilly                           Deluxe Double Room      Fabulous
# 18          Munnar                                 Cottage Room      Fabulous
# 19     Kazhakuttam                           Deluxe Double Room          Good
# 20          Alwaye                         Standard Double Room          Good
# 21        Kondotti                           Budget Double Room     Very good
# 22      Kattappana                         Standard Double Room  Review score
# 23         Wayanad                                  Deluxe Room      Fabulous
# 24          Ferokh                         Superior Double Room     Very good
# 25        Kakkanad                         Standard Double Room          Good
# 26       Ernakulam                                        Suite          Good
# 27    Mananthavady                   Double Room with Pool View        Superb
# 28         Vagamon              Deluxe Double Room with Balcony     Very good
# 29  Sultan Bathery                           Deluxe Double Room          Good
# 30         Vythiri                           Deluxe Double Room          Good
# 31    Vandiperiyār                         Deluxe Double Studio     Very good
# 32       Kanjikode                         Superior Double Room      Fabulous
# 33    Ūdumbanshola                                  Deluxe Room   Exceptional
# 34         Tariyod                                Superior Room          Good
# 35         Wayanad              Deluxe Double Room with Balcony          Good
# 36           Parūr  Deluxe Double or Twin Room with Pool Access        Superb
# 37           Pūvār                             Garden View Room          Good
# 38         Kallāyi                         Standard Double Room            NA
# 39         Wayanad                               Premium Villas      Fabulous
# 40      Thiruvalla                                Standard Room          Good
# 41        Palakkad                                  Deluxe Room     Very good
# 42       Kumarakom                     Cottage with Garden View     Very good
# 43     Ambalapulai                 Standard Double or Twin Room          Good
# 44    Athirappilly                           Deluxe Double Room      Fabulous
# 45          Munnar                                 Cottage Room      Fabulous
# 46     Kazhakuttam                           Deluxe Double Room          Good
# 47          Alwaye                         Standard Double Room          Good
# 48        Kondotti                           Budget Double Room     Very good
# 49      Kattappana                         Standard Double Room  Review score

# %%
df.to_csv("keral_dataset_saurav.csv")
